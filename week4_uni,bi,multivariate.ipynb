# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhaskar-459/ml_labs/blob/main/week4_uni%2Cbi%2Cmultivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df=pd.read_csv('BankChurners.csv')
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print('Customer_age')
print(df['Customer_Age'].unique())
print()
print('Credit_Limit')
print(df['Credit_Limit'].unique())
print()
print('Total_Revolving_Bal')
print(df['Total_Revolving_Bal'].unique())
# Out:
# Customer_age
# [45 49 51 40 44 32 37 48 42 65 56 35 57 41 61 47 62 54 59 63 53 58 55 66
#  50 38 46 52 39 43 64 68 67 60 73 70 36 34 33 26 31 29 30 28 27]
#
# Credit_Limit
# [12691.  8256.  3418. ...  5409.  5281. 10388.]
#
# Total_Revolving_Bal
# [ 777  864    0 ...  534  476 2241]

# %%
sns.countplot (x='Customer_Age', data=df)
# Out:
# <Axes: xlabel='Customer_Age', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
df.replace(np.nan, '0', inplace=True)
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
df.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
df[['Total_Revolving_Bal']].boxplot()
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
plt.hist (df['Credit_Limit'])
plt.xlabel('Credit_Limit')
plt.ylabel('count')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
Gender = 'M','F'
plt.pie(df['Gender'].value_counts(), labels=Gender)
# Out:
# ([<matplotlib.patches.Wedge at 0x7947b9f77940>,
# ...
#  [Text(-0.10035590564411713, 1.0954125671190509, 'M'),
#   Text(0.10035590564411676, -1.095412567119051, 'F')])

# %%
plt.figure()
df['Credit_Limit'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.scatter(x='Avg_Utilization_Ratio',y='Credit_Limit',data=df)

# %%
sns.violinplot(x='Credit_Limit', y='Avg_Utilization_Ratio', data=df, orient='vertical')
# Out:
# <Axes: xlabel='Credit_Limit', ylabel='Avg_Utilization_Ratio'>

# %%
def multivariate_eda(df):
    plt.figure(figsize=(10, 8))
    sns.pairplot(df)
    plt.title('Multivariate EDA')
    plt.show()

multivariate_eda(df[['Customer_Age', 'Avg_Utilization_Ratio', 'Credit_Limit']])
